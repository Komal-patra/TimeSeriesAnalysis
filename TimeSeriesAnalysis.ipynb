# %%
pip install pmdarima

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import matplotlib.dates as mdates

from statsmodels.tsa.api import SimpleExpSmoothing, Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.tsa.api as smt
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
weather_data= pd.read_csv("weather.csv")

# %%
weather_data.head(10)
# Out:
#         date  maxtp(Maximum Air Temperature - degrees C)  \
# 0   1-Jan-42                                         9.7
# 1   2-Jan-42                                         9.9
# 2   3-Jan-42                                        11.2
# 3   4-Jan-42                                         9.2
# 4   5-Jan-42                                         3.5
# 5   6-Jan-42                                         5.1
# 6   7-Jan-42                                         7.1
# 7   8-Jan-42                                         7.1
# 8   9-Jan-42                                         4.5
# 9  10-Jan-42                                         5.3
#
#    mintp(Minimum Air Temperature - degrees C)  \
# 0                                         6.8
# 1                                         7.9
# 2                                         8.9
# 3                                         2.7
# 4                                        -0.8
# 5                                         0.7
# 6                                         0.5
# 7                                         1.4
# 8                                         0.7
# 9                                        -2.8
#
#   gmin(Grass Minimum Temperature - degrees C)  \
# 0                                         4.7
# 1                                         6.7
# 2                                         7.2
# 3                                         3.4
# 4                                           0
# 5                                        -3.7
# 6                                          -1
# 7                                         0.2
# 8                                         0.9
# 9                                        -4.1
#
#    rain(Precipitation Amount - mm)  cbl (Mean CBL Pressure-hpa)  \
# 0                              0.0                       1020.3
# 1                              0.1                       1016.2
# 2                              1.5                       1006.8
# 3                              3.5                       1001.5
# 4                              0.6                       1013.4
# 5                              0.0                       1021.1
# 6                              0.0                       1021.7
# 7                              0.0                       1016.8
# 8                              0.2                       1012.0
# 9                              0.0                       1015.9
#
#    wdsp(Mean Wind Speed - knot)  pe(Potential Evapotranspiration - mm)  \
# 0                          17.2                                    1.1
# 1                          15.2                                    0.7
# 2                          14.0                                    0.5
# 3                          17.0                                    0.6
# 4                          13.0                                    0.6
# 5                           9.7                                    0.4
# 6                          10.3                                    0.2
# 7                           9.3                                    0.2
# 8                          11.8                                    0.5
# 9                           4.0                                    0.0
#
#   evap(Evaporation -mm)
# 0                   1.4
# 1                   0.9
# 2                   0.6
# 3                   0.7
# 4                   0.7
# 5                   0.5
# 6                   0.2
# 7                   0.2
# 8                   0.7
# 9                   0.1

# %%
weather_data.shape
# Out:
# (29889, 9)

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29889 entries, 0 to 29888
# Data columns (total 9 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   date                                         29889 non-null  object
#  1   maxtp(Maximum Air Temperature - degrees C)   29889 non-null  float64
#  2   mintp(Minimum Air Temperature - degrees C)   29889 non-null  float64
#  3   gmin(Grass Minimum Temperature - degrees C)  29889 non-null  object
#  4   rain(Precipitation Amount - mm)              29889 non-null  float64
#  5   cbl (Mean CBL Pressure-hpa)                  29889 non-null  float64
#  6   wdsp(Mean Wind Speed - knot)                 29889 non-null  float64
#  7   pe(Potential Evapotranspiration - mm)        29889 non-null  float64
#  8   evap(Evaporation -mm)                        29889 non-null  object
# dtypes: float64(6), object(3)
# memory usage: 2.1+ MB

# %%
weather_data.isnull().sum()
# Out:
# date                                           0
# maxtp(Maximum Air Temperature - degrees C)     0
# mintp(Minimum Air Temperature - degrees C)     0
# gmin(Grass Minimum Temperature - degrees C)    0
# rain(Precipitation Amount - mm)                0
# cbl (Mean CBL Pressure-hpa)                    0
# wdsp(Mean Wind Speed - knot)                   0
# pe(Potential Evapotranspiration - mm)          0
# evap(Evaporation -mm)                          0
# dtype: int64

# %%
# function for processing the dataframe in order to parse the dates , adjusting the year from 1942 to 2023
def parse_dates(date):
    try:
        return pd.to_datetime(date, format='%d-%b-%y')
    except ValueError:
        return pd.NaT

# Applying the date parsing function to the 'date' column 
weather_data['date'] = weather_data['date'].apply(parse_dates)
weather_data.dropna(subset=['date'], inplace=True)

# Adjust the year for dates that are incorrectly parsed as 21st century
weather_data['date'] = weather_data['date'].apply(lambda d: d.replace(year=d.year - 100) if d.year > 2023 else d)

# Extract the year from the 'date' column
weather_data['year'] = weather_data['date'].dt.year

print(weather_data.head())

# Checking for unique years 
unique_years = weather_data['year'].unique()
unique_years.sort()
print('Unique years in the dataset after adjustment:', unique_years)
# Out:
#         date  maxtp(Maximum Air Temperature - degrees C)  \
# 0 1942-01-01                                         9.7
# 1 1942-01-02                                         9.9
# 2 1942-01-03                                        11.2
# 3 1942-01-04                                         9.2
# 4 1942-01-05                                         3.5
#
#    mintp(Minimum Air Temperature - degrees C)  \
# 0                                         6.8
# 1                                         7.9
# 2                                         8.9
# 3                                         2.7
# 4                                        -0.8
#
#   gmin(Grass Minimum Temperature - degrees C)  \
# 0                                         4.7
# 1                                         6.7
# 2                                         7.2
# 3                                         3.4
# 4                                           0
#
#    rain(Precipitation Amount - mm)  cbl (Mean CBL Pressure-hpa)  \
# 0                              0.0                       1020.3
# 1                              0.1                       1016.2
# 2                              1.5                       1006.8
# 3                              3.5                       1001.5
# 4                              0.6                       1013.4
#
#    wdsp(Mean Wind Speed - knot)  pe(Potential Evapotranspiration - mm)  \
# 0                          17.2                                    1.1
# 1                          15.2                                    0.7
# 2                          14.0                                    0.5
# 3                          17.0                                    0.6
# 4                          13.0                                    0.6
#
#   evap(Evaporation -mm)  year
# 0                   1.4  1942
# 1                   0.9  1942
# 2                   0.6  1942
# 3                   0.7  1942
# 4                   0.7  1942
# Unique years in the dataset after adjustment: [1942 1943 1944 1945 1946 1947 1948 1949 1950 1951 1952 1953 1954 1955
#  1956 1957 1958 1959 1960 1961 1962 1963 1964 1965 1966 1967 1968 1969
#  1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983
#  1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997
#  1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011
#  2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023]

# %%
#renaming the column name for better understanding
weather_data.rename(columns={
    'maxtp(Maximum Air Temperature - degrees C)': 'maxtp',
    'mintp(Minimum Air Temperature - degrees C)': 'mintp',
    'gmin(Grass Minimum Temperature - degrees C)': 'gmin',
    'rain(Precipitation Amount - mm)': 'rain',
    'cbl (Mean CBL Pressure-hpa)': 'cbl',
    'wdsp(Mean Wind Speed - knot)': 'wdsp',
    'pe(Potential Evapotranspiration - mm)': 'pe',
    'evap(Evaporation -mm)': 'evap',
    'year': 'year'
}, inplace=True)

# %%
weather_data
# Out:
#             date  maxtp  mintp  gmin  rain     cbl  wdsp   pe evap  year
# 0     1942-01-01    9.7    6.8   4.7   0.0  1020.3  17.2  1.1  1.4  1942
# 1     1942-01-02    9.9    7.9   6.7   0.1  1016.2  15.2  0.7  0.9  1942
# 2     1942-01-03   11.2    8.9   7.2   1.5  1006.8  14.0  0.5  0.6  1942
# 3     1942-01-04    9.2    2.7   3.4   3.5  1001.5  17.0  0.6  0.7  1942
# 4     1942-01-05    3.5   -0.8     0   0.6  1013.4  13.0  0.6  0.7  1942
# ...          ...    ...    ...   ...   ...     ...   ...  ...  ...   ...
# 29884 2023-10-27   13.2    4.1    -1   2.9   974.2   5.8  0.5  0.8  2023
# 29885 2023-10-28   14.1    9.3   7.2   4.4   970.1   8.5  0.7    1  2023
# 29886 2023-10-29   12.4    2.5  -1.2  11.1   972.0   5.2  0.4  0.6  2023
# 29887 2023-10-30   12.7    1.7  -1.3   2.1   979.9   4.1  0.3  0.5  2023
# 29888 2023-10-31   12.3    4.4   0.8   4.2   983.2   6.8  0.4  0.5  2023
#
# [29889 rows x 10 columns]

# %%
weather_data['year'].unique()
# Out:
# array([1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952,
#        1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963,
#        1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974,
#        1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985,
#        1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996,
#        1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021, 2022, 2023])

# %%
print(weather_data['year'].min())
# Out:
# 1942

# %%
print(weather_data['year'].max())
# Out:
# 2023

# %%
weather_data.dtypes
# Out:
# date     datetime64[ns]
# maxtp           float64
# mintp           float64
# gmin             object
# rain            float64
# cbl             float64
# wdsp            float64
# pe              float64
# evap             object
# year              int32
# dtype: object

# %%
plt.figure(figsize=(10, 6))
sns.histplot(weather_data['wdsp'].dropna(), kde=True)
plt.title('Histogram of Mean Wind Speed (wdsp)')
plt.xlabel('Mean Wind Speed (knot)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\nikhi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Preliminary assessment and component of the raw time series

# %%
weather_data_df = weather_data.copy()

# %%
# Create a range of years from 2019 to 2023
year_range = range(2019, 2023)

# Set 'year' as the index and filter only the rows within the specified range
weather_data_df.set_index('year', inplace=True)
weather_data_df = weather_data_df.loc[year_range]

# Resetting the index if needed
weather_data_df.reset_index(inplace=True)

# Display the updated DataFrame
print(weather_data_df)
# Out:
#       year       date  maxtp  mintp  gmin  rain     cbl  wdsp   pe evap
# 0     2019 2019-01-01    9.2    1.8   6.9   0.2  1027.8   7.5  0.3  0.4
# 1     2019 2019-01-02    7.6    1.6    -1   0.0  1032.6   4.2  0.5  0.6
# 2     2019 2019-01-03    7.9    4.9  -1.6   0.0  1031.1   4.0  0.5  0.6
# 3     2019 2019-01-04    6.5    4.6   4.2   0.0  1030.9   4.8  0.7  0.9
# 4     2019 2019-01-05    8.4    2.0  -1.9   0.0  1027.7   5.2  0.4  0.5
# ...    ...        ...    ...    ...   ...   ...     ...   ...  ...  ...
# 1456  2022 2022-12-27   11.1    2.0   0.1   1.0  1001.0   9.5  0.5  0.6
# 1457  2022 2022-12-28   11.3    5.0     2   5.2   983.5   9.8  0.5  0.6
# 1458  2022 2022-12-29    9.6    4.7   3.2   0.8   982.6  12.2  0.7  0.8
# 1459  2022 2022-12-30   11.4    6.9   3.1   2.5   975.3  12.8  0.8  0.9
# 1460  2022 2022-12-31   10.0    5.3   4.4   2.6   982.7   3.7  0.3  0.4
#
# [1461 rows x 10 columns]

# %%
weather_data_df
# Out:
#       year       date  maxtp  mintp  gmin  rain     cbl  wdsp   pe evap
# 0     2019 2019-01-01    9.2    1.8   6.9   0.2  1027.8   7.5  0.3  0.4
# 1     2019 2019-01-02    7.6    1.6    -1   0.0  1032.6   4.2  0.5  0.6
# 2     2019 2019-01-03    7.9    4.9  -1.6   0.0  1031.1   4.0  0.5  0.6
# 3     2019 2019-01-04    6.5    4.6   4.2   0.0  1030.9   4.8  0.7  0.9
# 4     2019 2019-01-05    8.4    2.0  -1.9   0.0  1027.7   5.2  0.4  0.5
# ...    ...        ...    ...    ...   ...   ...     ...   ...  ...  ...
# 1456  2022 2022-12-27   11.1    2.0   0.1   1.0  1001.0   9.5  0.5  0.6
# 1457  2022 2022-12-28   11.3    5.0     2   5.2   983.5   9.8  0.5  0.6
# 1458  2022 2022-12-29    9.6    4.7   3.2   0.8   982.6  12.2  0.7  0.8
# 1459  2022 2022-12-30   11.4    6.9   3.1   2.5   975.3  12.8  0.8  0.9
# 1460  2022 2022-12-31   10.0    5.3   4.4   2.6   982.7   3.7  0.3  0.4
#
# [1461 rows x 10 columns]

# %%
weather_data_df.shape
# Out:
# (1461, 10)

# %%
import matplotlib.pyplot as plt

# Assuming 'weather_data_df' is your DataFrame
plt.figure(figsize=(10, 6))
plt.plot(weather_data_df['date'], weather_data_df['wdsp'], label='Wind Speed')
plt.title('Wind Speed Over Time')
plt.xlabel('Date')
plt.ylabel('Wind Speed')
plt.legend()
plt.show()

# %%
smt.graphics.plot_acf(weather_data_df['wdsp']);

# %%
smt.graphics.plot_pacf(weather_data_df['wdsp']);

# %%
weather_decompose = weather_data_df.copy()

# %%
weather_decompose.set_index('date', inplace=True)

# %%
#### Decomposing the mean wind speed into 3 components
decompose = seasonal_decompose(weather_decompose['wdsp'])

# %%
decompose.plot();

# %%
# Performing seasonal decomposition using an additive model
result_add = seasonal_decompose(weather_decompose['wdsp'].dropna(), model='additive', period=365)

# %%
result_add.plot();

# %% [markdown]
# ### Model 1: Simple Time Series Model

# %%
weather_model1 = weather_data.copy()

# %%
weather_model1
# Out:
#             date  maxtp  mintp  gmin  rain     cbl  wdsp   pe evap  year
# 0     1942-01-01    9.7    6.8   4.7   0.0  1020.3  17.2  1.1  1.4  1942
# 1     1942-01-02    9.9    7.9   6.7   0.1  1016.2  15.2  0.7  0.9  1942
# 2     1942-01-03   11.2    8.9   7.2   1.5  1006.8  14.0  0.5  0.6  1942
# 3     1942-01-04    9.2    2.7   3.4   3.5  1001.5  17.0  0.6  0.7  1942
# 4     1942-01-05    3.5   -0.8     0   0.6  1013.4  13.0  0.6  0.7  1942
# ...          ...    ...    ...   ...   ...     ...   ...  ...  ...   ...
# 29884 2023-10-27   13.2    4.1    -1   2.9   974.2   5.8  0.5  0.8  2023
# 29885 2023-10-28   14.1    9.3   7.2   4.4   970.1   8.5  0.7    1  2023
# 29886 2023-10-29   12.4    2.5  -1.2  11.1   972.0   5.2  0.4  0.6  2023
# 29887 2023-10-30   12.7    1.7  -1.3   2.1   979.9   4.1  0.3  0.5  2023
# 29888 2023-10-31   12.3    4.4   0.8   4.2   983.2   6.8  0.4  0.5  2023
#
# [29889 rows x 10 columns]

# %%
# Creating a range of years from 2019 to 2023
year_range = range(2019, 2023)

# Setting 'year' as the index 
weather_model1.set_index('year', inplace=True)
# setting the index range from the year 2019 to 2023
weather_model1 = weather_model1.loc[year_range]

# Resetting the index
weather_model1.reset_index(inplace=True)

# Displaying the modified DataFrame
print(weather_model1)
# Out:
#       year       date  maxtp  mintp  gmin  rain     cbl  wdsp   pe evap
# 0     2019 2019-01-01    9.2    1.8   6.9   0.2  1027.8   7.5  0.3  0.4
# 1     2019 2019-01-02    7.6    1.6    -1   0.0  1032.6   4.2  0.5  0.6
# 2     2019 2019-01-03    7.9    4.9  -1.6   0.0  1031.1   4.0  0.5  0.6
# 3     2019 2019-01-04    6.5    4.6   4.2   0.0  1030.9   4.8  0.7  0.9
# 4     2019 2019-01-05    8.4    2.0  -1.9   0.0  1027.7   5.2  0.4  0.5
# ...    ...        ...    ...    ...   ...   ...     ...   ...  ...  ...
# 1456  2022 2022-12-27   11.1    2.0   0.1   1.0  1001.0   9.5  0.5  0.6
# 1457  2022 2022-12-28   11.3    5.0     2   5.2   983.5   9.8  0.5  0.6
# 1458  2022 2022-12-29    9.6    4.7   3.2   0.8   982.6  12.2  0.7  0.8
# 1459  2022 2022-12-30   11.4    6.9   3.1   2.5   975.3  12.8  0.8  0.9
# 1460  2022 2022-12-31   10.0    5.3   4.4   2.6   982.7   3.7  0.3  0.4
#
# [1461 rows x 10 columns]

# %% [markdown]
# #### A. Simple Moving Average

# %%
# Calculating the simple moving average for 'wdsp' with a window size of 365 days
weather_model1['SMA'] = weather_model1['wdsp'].rolling(window=365, min_periods=1).mean()
weather_model1['SMA_6months'] = weather_model1['wdsp'].rolling(window=182, min_periods=1).mean()

# %%
# Plotting the original and SMA time series
plt.figure(figsize=(15, 8))
plt.plot(weather_model1['date'], weather_model1['wdsp'], label='Original Wind Speed', alpha=0.5)
plt.plot(weather_model1['date'], weather_model1['SMA'], label='SMA (365 days)', color='red')
plt.plot(weather_model1['date'], weather_model1['SMA_6months'], label='SMA (6 months)', color='green')
plt.title('Original and SMA Wind Speed Time Series')
plt.xlabel('Year')
plt.ylabel('Wind Speed (knots)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
weather_model1.set_index('year', inplace=True)

sma_mean_absolute_error = mean_absolute_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["SMA"]
)
sma_root_mean_squared_error = mean_squared_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["SMA"]
)**0.5
sma_mean_absolute_perc_error = mean_absolute_percentage_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["SMA"]
) 

print(" SMA- MAE:{:.3f}, RMSE : {:.3f}, MAPE : {:.3f}".format(sma_mean_absolute_error, sma_root_mean_squared_error
                                                             , sma_mean_absolute_perc_error))
# Out:
#  SMA- MAE:2.748, RMSE : 3.392, MAPE : 0.352

# %% [markdown]
# #### B. Weighted Moving Average (WMA)

# %%
weather_model1['WMA'] = weather_model1['wdsp'].rolling(window=365, min_periods=1).apply(lambda x: np.average(x, weights=np.arange(1, len(x) + 1)))

# %%
# Plotting the original, SMA, and WMA time series
plt.figure(figsize=(10, 6))
plt.plot(weather_model1['date'], weather_model1['wdsp'], label='Original Wind Speed', alpha=0.5)
plt.plot(weather_model1['date'], weather_model1['WMA'], label='WMA (365 days)', color='green')
plt.title('Wind Speed Time Series with SMA and WMA')
plt.xlabel('Date')
plt.ylabel('Wind Speed (knots)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
weather_model1 = weather_model1.loc[2019:].dropna(subset=["wdsp", "WMA"])

wma_mean_absolute_error = mean_absolute_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["WMA"]
)
wma_root_mean_squared_error = mean_squared_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["WMA"]
)**0.5
wma_mean_absolute_perc_error = mean_absolute_percentage_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["WMA"]
) 

print(" WMA- MAE:{:.3f}, RMSE : {:.3f}, MAPE : {:.3f}".format(wma_mean_absolute_error, wma_root_mean_squared_error
                                                             , wma_mean_absolute_perc_error))
# Out:
#  WMA- MAE:2.721, RMSE : 3.364, MAPE : 0.348

# %% [markdown]
# #### C. Exponential Weighted Moving Average

# %%
# Calculating the weighted moving average for 'wdsp'. We will use the exponentially weighted moving average (EWMA) as a form of WMA.
weather_model1['Exp_WMA'] = weather_model1['wdsp'].ewm(span=365, adjust=False).mean()

# %%
# Plotting the original, SMA, and WMA time series
plt.figure(figsize=(10, 6))

plt.plot(weather_model1['date'], weather_model1['Exp_WMA'], label='WMA (365 days)', color='green')
plt.title('Wind Speed Time Series with SMA and WMA')
plt.xlabel('Date')
plt.ylabel('Wind Speed (knots)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
weather_model1['WMA'] = weather_model1['wdsp'].rolling(window=365, min_periods=1).apply(lambda x: np.average(x, weights=np.arange(1, len(x) + 1)))


# Plotting the original, SMA, and WMA time series
plt.figure(figsize=(10, 6))
plt.plot(weather_model1['date'], weather_model1['wdsp'], label='Original Wind Speed', alpha=0.5)
#plt.plot(weather_model1['date'], weather_model1['SMA_6months'], label='SMA (6 months)', color='purple')
plt.plot(weather_model1['date'], weather_model1['SMA'], label='SMA (365 days)', color='red')
plt.plot(weather_model1['date'], weather_model1['WMA'], label='WMA (365 days)', color='green')
#plt.plot(weather_model1['date'], weather_model1['Exp_WMA'], label=' Exponential WMA (365 days)', color='yellow')
plt.title('Wind Speed Time Series with SMA, WMA and Exponential WMA')
plt.xlabel('Date')
plt.ylabel('Wind Speed (knots)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
weather_model1 = weather_model1.loc[2019:].dropna(subset=["wdsp", "WMA"])

Ewma_mean_absolute_error = mean_absolute_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["Exp_WMA"]
)
Ewma_root_mean_squared_error = mean_squared_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["Exp_WMA"]
)**0.5
Ewma_mean_absolute_perc_error = mean_absolute_percentage_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["Exp_WMA"]
) 

print(" Exponential WMA- MAE:{:.3f}, RMSE : {:.3f}, MAPE : {:.3f}".format(Ewma_mean_absolute_error, Ewma_root_mean_squared_error
                                                             , Ewma_mean_absolute_perc_error))
# Out:
#  Exponential WMA- MAE:2.733, RMSE : 3.402, MAPE : 0.342

# %% [markdown]
# #### Evaluation of Model 1

# %%
sma_mean_absolute_error = mean_absolute_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["SMA"]
)
sma_root_mean_squared_error = mean_squared_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["SMA"]
)**0.5
sma_mean_absolute_perc_error = mean_absolute_percentage_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["SMA"]
) 

print(" SMA- MAE:{:.3f}, RMSE : {:.3f}, MAPE : {:.3f}".format(sma_mean_absolute_error, sma_root_mean_squared_error
                                                             , sma_mean_absolute_perc_error))
# Out:
#  SMA- MAE:2.748, RMSE : 3.392, MAPE : 0.352

# %%
weather_model1 = weather_model1.loc[2019:].dropna(subset=["wdsp", "WMA"])

wma_mean_absolute_error = mean_absolute_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["WMA"]
)
wma_root_mean_squared_error = mean_squared_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["WMA"]
)**0.5
wma_mean_absolute_perc_error = mean_absolute_percentage_error(
    weather_model1.loc[2019:]["wdsp"],
    weather_model1.loc[2019:]["WMA"]
) 

print(" WMA- MAE:{:.3f}, RMSE : {:.3f}, MAPE : {:.3f}".format(wma_mean_absolute_error, wma_root_mean_squared_error
                                                             , wma_mean_absolute_perc_error))
# Out:
#  WMA- MAE:2.721, RMSE : 3.364, MAPE : 0.348

# %% [markdown]
# ### Model 2: Simple Exponential Smoothening

# %%
weather_model2 = weather_data_df.copy()

# %%
weather_model2
# Out:
#       year       date  maxtp  mintp  gmin  rain     cbl  wdsp   pe evap
# 0     2019 2019-01-01    9.2    1.8   6.9   0.2  1027.8   7.5  0.3  0.4
# 1     2019 2019-01-02    7.6    1.6    -1   0.0  1032.6   4.2  0.5  0.6
# 2     2019 2019-01-03    7.9    4.9  -1.6   0.0  1031.1   4.0  0.5  0.6
# 3     2019 2019-01-04    6.5    4.6   4.2   0.0  1030.9   4.8  0.7  0.9
# 4     2019 2019-01-05    8.4    2.0  -1.9   0.0  1027.7   5.2  0.4  0.5
# ...    ...        ...    ...    ...   ...   ...     ...   ...  ...  ...
# 1456  2022 2022-12-27   11.1    2.0   0.1   1.0  1001.0   9.5  0.5  0.6
# 1457  2022 2022-12-28   11.3    5.0     2   5.2   983.5   9.8  0.5  0.6
# 1458  2022 2022-12-29    9.6    4.7   3.2   0.8   982.6  12.2  0.7  0.8
# 1459  2022 2022-12-30   11.4    6.9   3.1   2.5   975.3  12.8  0.8  0.9
# 1460  2022 2022-12-31   10.0    5.3   4.4   2.6   982.7   3.7  0.3  0.4
#
# [1461 rows x 10 columns]

# %%
weather_data_df.set_index('date', inplace=True)

# %%
weather_data_df.sort_index(inplace=True)

# %%
# Filtering the data to include only 2019 to 2022
start_date = '2019-01-01'
end_date = '2022-12-31'
weather_model2 = weather_data_df[start_date:end_date]

# %%
# Applying Simple Exponential Smoothing
ses_model = SimpleExpSmoothing(weather_model2['wdsp'], initialization_method='legacy-heuristic').fit()
# Out:
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
print(ses_model.summary())
# Out:
#                        SimpleExpSmoothing Model Results
# ==============================================================================
# Dep. Variable:                   wdsp   No. Observations:                 1461
# Model:             SimpleExpSmoothing   SSE                          14550.374
# Optimized:                       True   AIC                           3362.102
# Trend:                           None   BIC                           3372.676
# Seasonal:                        None   AICC                          3362.129
# Seasonal Periods:                None   Date:                 Tue, 02 Jan 2024
# Box-Cox:                        False   Time:                         23:44:30
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.3913006                alpha                 True
# initial_level              7.5000000                  l.0                False
# ------------------------------------------------------------------------------

# %%
# Forecasting using the fitted SES model for the year 2023
forecast_2023 = ses_model.forecast(365)

# %%
# Reseting index to use 'date' in plotting
weather_model2.reset_index(inplace=True)
forecast_2023_df = pd.DataFrame({'date': pd.date_range(start='2023-01-01', periods=365, freq='D'), 'forecast': forecast_2023})

# %% [markdown]
# Having produced the forecast, we can plot the original series, the smoothed series along with the forecast.

# %%
# Ploting the original, SES forecast, and extended forecast time series
plt.figure(figsize=(10, 6))
plt.plot(weather_model2['date'], weather_model2['wdsp'], label='Original Wind Speed (2019-2022)')
plt.plot(weather_model2['date'], ses_model.fittedvalues, label='SES Fitted', color='orange')
plt.plot(forecast_2023_df['date'], forecast_2023_df['forecast'], label='Forecast for 2023', color='red', linestyle='--')
plt.title('Wind Speed Data Fitted and Forecasted (2019-2022, 2023)')
plt.xlabel('Date')
plt.ylabel('Wind Speed (knots)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# The forecast is flat.This is because the simple exponential smoothing model is not capable of capturing the trend in the data.

# %% [markdown]
# Evaluating the model by calculating the MAE, RMSE and MAPE for the fitted model.

# %% [markdown]
# #### Evaluation of Model 2

# %%
# Evaluation of the  single exponential smoothing
ses_mean_absolute_error = mean_absolute_error(
    weather_model2["wdsp"],
    ses_model.fittedvalues
)
ses_root_mean_squared_error = mean_squared_error(
    weather_model2["wdsp"],
    ses_model.fittedvalues)**0.5
ses_mean_absolute_perc_error = mean_absolute_percentage_error(
    weather_model2["wdsp"],
    ses_model.fittedvalues
) 

print(" SES- MAE:{:.3f}, RMSE : {:.3f}, MAPE : {:.3f}".format(ses_mean_absolute_error, ses_root_mean_squared_error
                                                             , ses_mean_absolute_perc_error))
# Out:
#  SES- MAE:2.477, RMSE : 3.156, MAPE : 0.304

# %% [markdown]
# ### Model 3: Holt Linear's trend (Double Exponential Smoothing)

# %% [markdown]
# Double Exponential smoothing is also known as Holt's Linear Trend model, using the column 'mean wind speed (wdsp)'

# %%
weather_model3 = weather_data_df.copy()

# %%
weather_model3
# Out:
#             year  maxtp  mintp  gmin  rain     cbl  wdsp   pe evap
# date
# 2019-01-01  2019    9.2    1.8   6.9   0.2  1027.8   7.5  0.3  0.4
# 2019-01-02  2019    7.6    1.6    -1   0.0  1032.6   4.2  0.5  0.6
# 2019-01-03  2019    7.9    4.9  -1.6   0.0  1031.1   4.0  0.5  0.6
# 2019-01-04  2019    6.5    4.6   4.2   0.0  1030.9   4.8  0.7  0.9
# 2019-01-05  2019    8.4    2.0  -1.9   0.0  1027.7   5.2  0.4  0.5
# ...          ...    ...    ...   ...   ...     ...   ...  ...  ...
# 2022-12-27  2022   11.1    2.0   0.1   1.0  1001.0   9.5  0.5  0.6
# 2022-12-28  2022   11.3    5.0     2   5.2   983.5   9.8  0.5  0.6
# 2022-12-29  2022    9.6    4.7   3.2   0.8   982.6  12.2  0.7  0.8
# 2022-12-30  2022   11.4    6.9   3.1   2.5   975.3  12.8  0.8  0.9
# 2022-12-31  2022   10.0    5.3   4.4   2.6   982.7   3.7  0.3  0.4
#
# [1461 rows x 9 columns]

# %%
weather_data_df.sort_index(inplace=True)

# %%
# Filtering the data to include only 2019 to 2022
start_date = '2019-01-01'
end_date = '2022-12-31'
weather_model3 = weather_data_df[start_date:end_date]

# %%
# Apply Holt's Linear Trend method

fit_holt_model = Holt(weather_model3["wdsp"]).fit()
# Out:
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
print(fit_holt_model.summary())
# Out:
#                               Holt Model Results
# ==============================================================================
# Dep. Variable:                   wdsp   No. Observations:                 1461
# Model:                           Holt   SSE                          15750.683
# Optimized:                       True   AIC                           3481.911
# Trend:                       Additive   BIC                           3503.059
# Seasonal:                        None   AICC                          3481.969
# Seasonal Periods:                None   Date:                 Tue, 02 Jan 2024
# Box-Cox:                        False   Time:                         23:44:30
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5402752                alpha                 True
# smoothing_trend            0.0377368                 beta                 True
# initial_level              7.5000000                  l.0                False
# initial_trend             -3.3000000                  b.0                False
# ------------------------------------------------------------------------------

# %%
# Forecasting for the year 2023
forecast_2023_holt = fit_holt_model.forecast(365)
print(forecast_2023_holt)
# Out:
# 2023-01-01     7.513447
# 2023-01-02     7.453176
# 2023-01-03     7.392905
# 2023-01-04     7.332635
# 2023-01-05     7.272364
#                 ...
# 2023-12-27   -14.184096
# 2023-12-28   -14.244367
# 2023-12-29   -14.304638
# 2023-12-30   -14.364909
# 2023-12-31   -14.425180
# Freq: D, Length: 365, dtype: float64

# %%
# Reseting index to use 'date' in plotting
weather_model3.reset_index(inplace=True)
forecast_2023_holt_df = pd.DataFrame({'date': pd.date_range(start='2023-01-01', periods=365, freq='D'), 'forecast': forecast_2023_holt})

# %%
# Ploting the fitted model and the forecast
plt.figure(figsize=(10, 6))
plt.plot(weather_model3['date'], weather_model3['wdsp'], label='Original Wind Speed (2019-2022)')
plt.plot(weather_model3['date'], fit_holt_model.fittedvalues, label='Holt Linear', color='green')
plt.plot(forecast_2023_holt_df['date'], forecast_2023_holt_df['forecast'], label='Forecast for 2023', color='blue', linestyle='--')
plt.title('Wind Speed Data Fitted and Forecasted with Holt Linear Trend (2019-2022, 2023)')
plt.xlabel('Date')
plt.ylabel('Wind Speed (knots)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Evaluation of Model 3

# %%
holt_mean_absolute_error = mean_absolute_error(
    weather_model3["wdsp"],
    fit_holt_model.fittedvalues
)
holt_root_mean_squared_error = mean_squared_error(
    weather_model3["wdsp"],
    fit_holt_model.fittedvalues
)
holt_mean_absolute_perecentage_error = mean_absolute_percentage_error(
    weather_model3["wdsp"],
    fit_holt_model.fittedvalues
)

print(" SES- MAE:{:.3f}, RMSE : {:.3f}, MAPE : {:.3f}".format(holt_mean_absolute_error, holt_root_mean_squared_error
                                                             , holt_mean_absolute_perecentage_error))
# Out:
#  SES- MAE:2.550, RMSE : 10.781, MAPE : 0.308

# %% [markdown]
# ### Model 4: Triple Exponential Smoothing

# %%
weather_model4 = weather_data.copy()

# %%
weather_model4
# Out:
#             date  maxtp  mintp  gmin  rain     cbl  wdsp   pe evap  year
# 0     1942-01-01    9.7    6.8   4.7   0.0  1020.3  17.2  1.1  1.4  1942
# 1     1942-01-02    9.9    7.9   6.7   0.1  1016.2  15.2  0.7  0.9  1942
# 2     1942-01-03   11.2    8.9   7.2   1.5  1006.8  14.0  0.5  0.6  1942
# 3     1942-01-04    9.2    2.7   3.4   3.5  1001.5  17.0  0.6  0.7  1942
# 4     1942-01-05    3.5   -0.8     0   0.6  1013.4  13.0  0.6  0.7  1942
# ...          ...    ...    ...   ...   ...     ...   ...  ...  ...   ...
# 29884 2023-10-27   13.2    4.1    -1   2.9   974.2   5.8  0.5  0.8  2023
# 29885 2023-10-28   14.1    9.3   7.2   4.4   970.1   8.5  0.7    1  2023
# 29886 2023-10-29   12.4    2.5  -1.2  11.1   972.0   5.2  0.4  0.6  2023
# 29887 2023-10-30   12.7    1.7  -1.3   2.1   979.9   4.1  0.3  0.5  2023
# 29888 2023-10-31   12.3    4.4   0.8   4.2   983.2   6.8  0.4  0.5  2023
#
# [29889 rows x 10 columns]

# %%
year_range = range(2019, 2024)

# Setting 'year' as the index and filter only the rows within the specified range
weather_model4.set_index("year", inplace=True)
weather_model4 = weather_model4.loc[year_range]

# Resetting the index if needed
weather_model4.reset_index(inplace=True)

# %%
weather_model4['date'] = pd.to_datetime(weather_model4['date'], format='%Y-%m-%d')
weather_model4.set_index('date', inplace=True)

# %%
# splitting the dataset into train (from year 2019 to 2022) and test as year 2023 in order to forecast 
train = weather_model4['wdsp'].loc["2019-01-01":"2022-12-31"]
print(train)
test = weather_model4['wdsp'].loc["2023-01-01":"2023-10-31"]
print(test)
# Out:
# date
# 2019-01-01     7.5
# 2019-01-02     4.2
# 2019-01-03     4.0
# 2019-01-04     4.8
# 2019-01-05     5.2
#               ...
# 2022-12-27     9.5
# 2022-12-28     9.8
# 2022-12-29    12.2
# 2022-12-30    12.8
# 2022-12-31     3.7
# Name: wdsp, Length: 1461, dtype: float64
# date
# 2023-01-01     5.5
# 2023-01-02     6.2
# 2023-01-03    12.5
# 2023-01-04    13.7
# 2023-01-05    10.3
#               ...
# 2023-10-27     5.8
# 2023-10-28     8.5
# 2023-10-29     5.2
# 2023-10-30     4.1
# 2023-10-31     6.8
# Name: wdsp, Length: 304, dtype: float64

# %%
train
# Out:
# date
# 2019-01-01     7.5
# 2019-01-02     4.2
# 2019-01-03     4.0
# 2019-01-04     4.8
# 2019-01-05     5.2
#               ...
# 2022-12-27     9.5
# 2022-12-28     9.8
# 2022-12-29    12.2
# 2022-12-30    12.8
# 2022-12-31     3.7
# Name: wdsp, Length: 1461, dtype: float64

# %%
test
# Out:
# date
# 2023-01-01     5.5
# 2023-01-02     6.2
# 2023-01-03    12.5
# 2023-01-04    13.7
# 2023-01-05    10.3
#               ...
# 2023-10-27     5.8
# 2023-10-28     8.5
# 2023-10-29     5.2
# 2023-10-30     4.1
# 2023-10-31     6.8
# Name: wdsp, Length: 304, dtype: float64

# %%
# Applying the triple exponential smoothing
fit_test = ExponentialSmoothing(train,
                                           trend='add',
                                           seasonal='add',
                                           seasonal_periods=365, 
                                           initialization_method='estimated').fit()
print(fit_test.summary());
# Out:
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                     wdsp   No. Observations:                 1461
# Model:             ExponentialSmoothing   SSE                          10880.590
# Optimized:                         True   AIC                           3671.482
# Trend:                         Additive   BIC                           5622.340
# Seasonal:                      Additive   AICC                          3924.948
# Seasonal Periods:                   365   Date:                 Tue, 02 Jan 2024
# Box-Cox:                          False   Time:                         23:44:32
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.2934835                alpha                 True
# smoothing_trend               6.2862e-07                 beta                 True
# smoothing_seasonal            3.5981e-06                gamma                 True
# initial_level                  5.9665713                  l.0                 True
# initial_trend                  0.0021655                  b.0                 True
# initial_seasons.0             -1.2159624                  s.0                 True
# initial_seasons.1              0.8042382                  s.1                 True
# initial_seasons.2              0.4713893                  s.2                 True
# initial_seasons.3             -0.1621215                  s.3                 True
# initial_seasons.4              0.9541133                  s.4                 True
# initial_seasons.5              0.4953494                  s.5                 True
# initial_seasons.6              2.7365471                  s.6                 True
# initial_seasons.7              0.0278370                  s.7                 True
# initial_seasons.8              0.7443949                  s.8                 True
# initial_seasons.9             -0.2636942                  s.9                 True
# initial_seasons.10             0.8788885                 s.10                 True
# initial_seasons.11             1.7467419                 s.11                 True
# initial_seasons.12             2.8148245                 s.12                 True
# initial_seasons.13            -0.5671158                 s.13                 True
# initial_seasons.14             0.7758078                 s.14                 True
# initial_seasons.15            -0.0564139                 s.15                 True
# initial_seasons.16             0.9113676                 s.16                 True
# initial_seasons.17            -1.8460597                 s.17                 True
# initial_seasons.18            -3.3534667                 s.18                 True
# initial_seasons.19            -0.3110577                 s.19                 True
# initial_seasons.20            -1.0687109                 s.20                 True
# initial_seasons.21            -0.0763691                 s.21                 True
# initial_seasons.22            -2.1840429                 s.22                 True
# initial_seasons.23            -1.5416228                 s.23                 True
# initial_seasons.24            -0.4992558                 s.24                 True
# initial_seasons.25            -1.0068082                 s.25                 True
# initial_seasons.26             2.4103785                 s.26                 True
# initial_seasons.27             0.4526304                 s.27                 True
# initial_seasons.28             1.2696058                 s.28                 True
# initial_seasons.29             2.9867359                 s.29                 True
# initial_seasons.30             5.4037282                 s.30                 True
# initial_seasons.31             3.6957412                 s.31                 True
# initial_seasons.32             2.5377529                 s.32                 True
# initial_seasons.33             1.1295471                 s.33                 True
# initial_seasons.34             1.7713168                 s.34                 True
# initial_seasons.35            -0.2871376                 s.35                 True
# initial_seasons.36            -0.3707194                 s.36                 True
# initial_seasons.37             4.6956301                 s.37                 True
# initial_seasons.38             7.1618462                 s.38                 True
# initial_seasons.39             5.9531736                 s.39                 True
# initial_seasons.40             4.8944078                 s.40                 True
# initial_seasons.41             2.5359473                 s.41                 True
# initial_seasons.42             3.0026407                 s.42                 True
# initial_seasons.43             3.8946541                 s.43                 True
# initial_seasons.44             2.5870839                 s.44                 True
# initial_seasons.45             5.4297053                 s.45                 True
# initial_seasons.46             3.4477227                 s.46                 True
# initial_seasons.47             6.2159267                 s.47                 True
# initial_seasons.48             2.7092381                 s.48                 True
# initial_seasons.49             3.8277904                 s.49                 True
# initial_seasons.50             3.7463239                 s.50                 True
# initial_seasons.51             5.4652103                 s.51                 True
# initial_seasons.52             4.9092592                 s.52                 True
# initial_seasons.53             1.7535970                 s.53                 True
# initial_seasons.54             5.0483964                 s.54                 True
# initial_seasons.55             1.6435188                 s.55                 True
# initial_seasons.56            -0.4858513                 s.56                 True
# initial_seasons.57             0.2601544                 s.57                 True
# initial_seasons.58            -0.3686026                 s.58                 True
# initial_seasons.59            -0.5220019                 s.59                 True
# initial_seasons.60             0.6996310                 s.60                 True
# initial_seasons.61            -0.0785212                 s.61                 True
# initial_seasons.62            -0.1565370                 s.62                 True
# initial_seasons.63            -0.5094063                 s.63                 True
# initial_seasons.64            -0.9118988                 s.64                 True
# initial_seasons.65            -0.0393297                 s.65                 True
# initial_seasons.66             1.0837737                 s.66                 True
# initial_seasons.67             2.9819891                 s.67                 True
# initial_seasons.68             3.7556410                 s.68                 True
# initial_seasons.69             3.4044707                 s.69                 True
# initial_seasons.70             5.0784970                 s.70                 True
# initial_seasons.71             6.6775210                 s.71                 True
# initial_seasons.72             6.3017323                 s.72                 True
# initial_seasons.73             3.7509055                 s.73                 True
# initial_seasons.74             2.3503558                 s.74                 True
# initial_seasons.75             2.2749703                 s.75                 True
# initial_seasons.76             0.8748715                 s.76                 True
# initial_seasons.77            -0.8249977                 s.77                 True
# initial_seasons.78            -0.9746556                 s.78                 True
# initial_seasons.79             0.0259266                 s.79                 True
# initial_seasons.80             0.4764404                 s.80                 True
# initial_seasons.81            -2.4978266                 s.81                 True
# initial_seasons.82            -0.1724601                 s.82                 True
# initial_seasons.83            -1.9470113                 s.83                 True
# initial_seasons.84            -2.2968788                 s.84                 True
# initial_seasons.85            -1.2967477                 s.85                 True
# initial_seasons.86            -0.5966800                 s.86                 True
# initial_seasons.87             1.1035761                 s.87                 True
# initial_seasons.88             0.8290495                 s.88                 True
# initial_seasons.89            -0.3951779                 s.89                 True
# initial_seasons.90            -1.0941886                 s.90                 True
# initial_seasons.91             2.2068912                 s.91                 True
# initial_seasons.92             2.3329865                 s.92                 True
# initial_seasons.93            -0.5161314                 s.93                 True
# initial_seasons.94             2.5347529                 s.94                 True
# initial_seasons.95             4.1603441                 s.95                 True
# initial_seasons.96             2.6358649                 s.96                 True
# initial_seasons.97             1.1862160                 s.97                 True
# initial_seasons.98            -0.1886416                 s.98                 True
# initial_seasons.99            -2.0635367                 s.99                 True
# initial_seasons.100           -3.0384167                s.100                 True
# initial_seasons.101           -0.3631914                s.101                 True
# initial_seasons.102            0.4120705                s.102                 True
# initial_seasons.103            0.5374178                s.103                 True
# initial_seasons.104           -1.2875871                s.104                 True
# initial_seasons.105           -2.6126199                s.105                 True
# initial_seasons.106           -2.4130033                s.106                 True
# initial_seasons.107           -1.2634097                s.107                 True
# initial_seasons.108           -3.3390046                s.108                 True
# initial_seasons.109           -3.5397361                s.109                 True
# initial_seasons.110           -1.6907636                s.110                 True
# initial_seasons.111            1.2079471                s.111                 True
# initial_seasons.112           -0.2686903                s.112                 True
# initial_seasons.113           -0.3706936                s.113                 True
# initial_seasons.114           -0.6729882                s.114                 True
# initial_seasons.115           -0.8754694                s.115                 True
# initial_seasons.116            1.2715272                s.116                 True
# initial_seasons.117           -2.0312468                s.117                 True
# initial_seasons.118           -0.5592457                s.118                 True
# initial_seasons.119           -2.1365982                s.119                 True
# initial_seasons.120           -1.4385949                s.120                 True
# initial_seasons.121           -1.3150655                s.121                 True
# initial_seasons.122           -2.7661738                s.122                 True
# initial_seasons.123           -0.9170411                s.123                 True
# initial_seasons.124            1.9072312                s.124                 True
# initial_seasons.125           -1.0935325                s.125                 True
# initial_seasons.126           -1.4441581                s.126                 True
# initial_seasons.127           -0.4450445                s.127                 True
# initial_seasons.128           -1.2957983                s.128                 True
# initial_seasons.129           -0.6967005                s.129                 True
# initial_seasons.130            2.0776764                s.130                 True
# initial_seasons.131            1.0024736                s.131                 True
# initial_seasons.132           -2.0222878                s.132                 True
# initial_seasons.133           -0.8463794                s.133                 True
# initial_seasons.134           -3.1200511                s.134                 True
# initial_seasons.135           -2.2431746                s.135                 True
# initial_seasons.136           -1.7660684                s.136                 True
# initial_seasons.137           -1.2387187                s.137                 True
# initial_seasons.138           -0.5613442                s.138                 True
# initial_seasons.139           -1.5590668                s.139                 True
# initial_seasons.140           -0.5069441                s.140                 True
# initial_seasons.141            0.2199554                s.141                 True
# initial_seasons.142            0.9217568                s.142                 True
# initial_seasons.143            0.7483454                s.143                 True
# initial_seasons.144            0.8750018                s.144                 True
# initial_seasons.145            2.0764081                s.145                 True
# initial_seasons.146            0.2777958                s.146                 True
# initial_seasons.147           -1.1709767                s.147                 True
# initial_seasons.148           -2.2197637                s.148                 True
# initial_seasons.149           -1.4934846                s.149                 True
# initial_seasons.150           -1.1422313                s.150                 True
# initial_seasons.151           -1.8157155                s.151                 True
# initial_seasons.152           -1.3643246                s.152                 True
# initial_seasons.153           -1.9127644                s.153                 True
# initial_seasons.154            0.1138235                s.154                 True
# initial_seasons.155            2.1403187                s.155                 True
# initial_seasons.156            0.8419619                s.156                 True
# initial_seasons.157           -0.5813974                s.157                 True
# initial_seasons.158           -0.5799372                s.158                 True
# initial_seasons.159           -0.5284144                s.159                 True
# initial_seasons.160           -2.0271943                s.160                 True
# initial_seasons.161            0.9489793                s.161                 True
# initial_seasons.162            3.3501082                s.162                 True
# initial_seasons.163            1.7512412                s.163                 True
# initial_seasons.164           -2.4225352                s.164                 True
# initial_seasons.165           -1.8711769                s.165                 True
# initial_seasons.166           -3.3197262                s.166                 True
# initial_seasons.167           -2.7682661                s.167                 True
# initial_seasons.168           -2.3417200                s.168                 True
# initial_seasons.169           -1.8652861                s.169                 True
# initial_seasons.170           -0.6388132                s.170                 True
# initial_seasons.171           -1.2624165                s.171                 True
# initial_seasons.172           -0.8860331                s.172                 True
# initial_seasons.173           -1.3097612                s.173                 True
# initial_seasons.174           -2.8085542                s.174                 True
# initial_seasons.175           -1.0075070                s.175                 True
# initial_seasons.176            0.8434664                s.176                 True
# initial_seasons.177            1.1693620                s.177                 True
# initial_seasons.178            0.0702580                s.178                 True
# initial_seasons.179           -0.1288095                s.179                 True
# initial_seasons.180            0.2470917                s.180                 True
# initial_seasons.181           -1.3770337                s.181                 True
# initial_seasons.182           -3.8013036                s.182                 True
# initial_seasons.183           -2.3006934                s.183                 True
# initial_seasons.184           -0.1500978                s.184                 True
# initial_seasons.185           -0.1245249                s.185                 True
# initial_seasons.186            1.6011847                s.186                 True
# initial_seasons.187            0.9517992                s.187                 True
# initial_seasons.188           -2.4225090                s.188                 True
# initial_seasons.189           -2.1470027                s.189                 True
# initial_seasons.190           -2.2216113                s.190                 True
# initial_seasons.191           -0.8962923                s.191                 True
# initial_seasons.192           -1.0462046                s.192                 True
# initial_seasons.193           -2.2713385                s.193                 True
# initial_seasons.194           -0.8467644                s.194                 True
# initial_seasons.195           -0.5975435                s.195                 True
# initial_seasons.196           -0.5735937                s.196                 True
# initial_seasons.197           -1.8997385                s.197                 True
# initial_seasons.198           -1.9259643                s.198                 True
# initial_seasons.199           -2.6021486                s.199                 True
# initial_seasons.200           -1.4782385                s.200                 True
# initial_seasons.201           -0.7043966                s.201                 True
# initial_seasons.202           -1.9803848                s.202                 True
# initial_seasons.203           -2.3314392                s.203                 True
# initial_seasons.204           -0.8574313                s.204                 True
# initial_seasons.205            0.1666553                s.205                 True
# initial_seasons.206           -0.1594493                s.206                 True
# initial_seasons.207           -1.6355258                s.207                 True
# initial_seasons.208           -0.4368279                s.208                 True
# initial_seasons.209           -0.4131661                s.209                 True
# initial_seasons.210           -1.4645894                s.210                 True
# initial_seasons.211           -0.8160577                s.211                 True
# initial_seasons.212           -2.7425029                s.212                 True
# initial_seasons.213           -2.1939662                s.213                 True
# initial_seasons.214           -1.4953484                s.214                 True
# initial_seasons.215           -2.0467247                s.215                 True
# initial_seasons.216            0.4270263                s.216                 True
# initial_seasons.217           -0.5491649                s.217                 True
# initial_seasons.218           -0.3251404                s.218                 True
# initial_seasons.219           -0.0760221                s.219                 True
# initial_seasons.220           -0.3516507                s.220                 True
# initial_seasons.221           -1.2521797                s.221                 True
# initial_seasons.222           -2.0275718                s.222                 True
# initial_seasons.223           -3.3529611                s.223                 True
# initial_seasons.224           -2.4034354                s.224                 True
# initial_seasons.225           -0.8540453                s.225                 True
# initial_seasons.226           -1.6548679                s.226                 True
# initial_seasons.227           -1.7058044                s.227                 True
# initial_seasons.228            1.9679704                s.228                 True
# initial_seasons.229            0.9168007                s.229                 True
# initial_seasons.230           -0.8595732                s.230                 True
# initial_seasons.231           -1.2858040                s.231                 True
# initial_seasons.232            1.5880421                s.232                 True
# initial_seasons.233           -0.5379196                s.233                 True
# initial_seasons.234           -1.8137355                s.234                 True
# initial_seasons.235           -2.1643713                s.235                 True
# initial_seasons.236           -3.2901271                s.236                 True
# initial_seasons.237           -1.0408558                s.237                 True
# initial_seasons.238           -1.7918128                s.238                 True
# initial_seasons.239           -3.0427905                s.239                 True
# initial_seasons.240           -1.1187950                s.240                 True
# initial_seasons.241            0.7053015                s.241                 True
# initial_seasons.242            0.2295246                s.242                 True
# initial_seasons.243           -0.3961088                s.243                 True
# initial_seasons.244           -0.7466739                s.244                 True
# initial_seasons.245           -1.1970938                s.245                 True
# initial_seasons.246            0.8275952                s.246                 True
# initial_seasons.247            0.6272911                s.247                 True
# initial_seasons.248            1.1521137                s.248                 True
# initial_seasons.249           -1.5981483                s.249                 True
# initial_seasons.250           -1.3733688                s.250                 True
# initial_seasons.251           -0.5736184                s.251                 True
# initial_seasons.252           -0.7488728                s.252                 True
# initial_seasons.253           -1.6240087                s.253                 True
# initial_seasons.254            0.0009544                s.254                 True
# initial_seasons.255           -2.4739571                s.255                 True
# initial_seasons.256           -1.6987520                s.256                 True
# initial_seasons.257           -2.4985612                s.257                 True
# initial_seasons.258           -2.8733580                s.258                 True
# initial_seasons.259           -2.0982269                s.259                 True
# initial_seasons.260           -2.9480863                s.260                 True
# initial_seasons.261           -2.1229387                s.261                 True
# initial_seasons.262           -1.0476271                s.262                 True
# initial_seasons.263           -1.2721982                s.263                 True
# initial_seasons.264           -2.0716859                s.264                 True
# initial_seasons.265           -1.2459504                s.265                 True
# initial_seasons.266           -1.8702769                s.266                 True
# initial_seasons.267           -0.4195155                s.267                 True
# initial_seasons.268            0.5061922                s.268                 True
# initial_seasons.269            2.0817849                s.269                 True
# initial_seasons.270           -0.2426734                s.270                 True
# initial_seasons.271            0.2577102                s.271                 True
# initial_seasons.272           -0.5169008                s.272                 True
# initial_seasons.273            2.6834758                s.273                 True
# initial_seasons.274           -0.9161853                s.274                 True
# initial_seasons.275            0.2342634                s.275                 True
# initial_seasons.276            1.4597033                s.276                 True
# initial_seasons.277            0.8351103                s.277                 True
# initial_seasons.278            2.7604591                s.278                 True
# initial_seasons.279            1.2606208                s.279                 True
# initial_seasons.280            1.1605526                s.280                 True
# initial_seasons.281           -0.5896568                s.281                 True
# initial_seasons.282            1.1847153                s.282                 True
# initial_seasons.283            1.2590598                s.283                 True
# initial_seasons.284           -2.8167891                s.284                 True
# initial_seasons.285           -0.9926328                s.285                 True
# initial_seasons.286           -1.5184360                s.286                 True
# initial_seasons.287           -1.1941544                s.287                 True
# initial_seasons.288           -1.7449884                s.288                 True
# initial_seasons.289           -1.3958430                s.289                 True
# initial_seasons.290           -0.2721463                s.290                 True
# initial_seasons.291           -2.0736349                s.291                 True
# initial_seasons.292            1.0992565                s.292                 True
# initial_seasons.293           -0.5529950                s.293                 True
# initial_seasons.294            0.9442478                s.294                 True
# initial_seasons.295            0.0914010                s.295                 True
# initial_seasons.296           -0.2366431                s.296                 True
# initial_seasons.297           -0.9147150                s.297                 True
# initial_seasons.298            0.2072225                s.298                 True
# initial_seasons.299            2.3542196                s.299                 True
# initial_seasons.300            1.0262637                s.300                 True
# initial_seasons.301            1.4982347                s.301                 True
# initial_seasons.302            1.6702092                s.302                 True
# initial_seasons.303           -0.6581185                s.303                 True
# initial_seasons.304            1.3884050                s.304                 True
# initial_seasons.305            1.3847514                s.305                 True
# initial_seasons.306            1.4056981                s.306                 True
# initial_seasons.307            0.9266591                s.307                 True
# initial_seasons.308           -0.0027336                s.308                 True
# initial_seasons.309           -2.5822538                s.309                 True
# initial_seasons.310            1.0382312                s.310                 True
# initial_seasons.311           -0.2166434                s.311                 True
# initial_seasons.312            0.6785518                s.312                 True
# initial_seasons.313           -0.6514694                s.313                 True
# initial_seasons.314            1.5933161                s.314                 True
# initial_seasons.315            4.3629819                s.315                 True
# initial_seasons.316            2.6824849                s.316                 True
# initial_seasons.317            2.1268605                s.317                 True
# initial_seasons.318           -0.0036796                s.318                 True
# initial_seasons.319           -1.1843439                s.319                 True
# initial_seasons.320           -1.2398372                s.320                 True
# initial_seasons.321            0.1796670                s.321                 True
# initial_seasons.322            2.3992041                s.322                 True
# initial_seasons.323            0.9438555                s.323                 True
# initial_seasons.324            0.7885088                s.324                 True
# initial_seasons.325            1.0831911                s.325                 True
# initial_seasons.326           -2.4970552                s.326                 True
# initial_seasons.327           -0.7024414                s.327                 True
# initial_seasons.328            0.5672960                s.328                 True
# initial_seasons.329            0.3120286                s.329                 True
# initial_seasons.330            1.8067948                s.330                 True
# initial_seasons.331            0.2767046                s.331                 True
# initial_seasons.332           -2.2283470                s.332                 True
# initial_seasons.333           -3.1582486                s.333                 True
# initial_seasons.334           -0.1630808                s.334                 True
# initial_seasons.335           -0.6427509                s.335                 True
# initial_seasons.336           -2.5473321                s.336                 True
# initial_seasons.337           -1.0519257                s.337                 True
# initial_seasons.338            5.4184925                s.338                 True
# initial_seasons.339            2.2137068                s.339                 True
# initial_seasons.340           -0.0410855                s.340                 True
# initial_seasons.341            2.7789689                s.341                 True
# initial_seasons.342            5.0741183                s.342                 True
# initial_seasons.343            1.3693637                s.343                 True
# initial_seasons.344            0.3398423                s.344                 True
# initial_seasons.345           -1.6395664                s.345                 True
# initial_seasons.346            0.5063305                s.346                 True
# initial_seasons.347           -0.5477354                s.347                 True
# initial_seasons.348            0.0483975                s.348                 True
# initial_seasons.349           -0.6304929                s.349                 True
# initial_seasons.350           -2.0595117                s.350                 True
# initial_seasons.351           -0.0635503                s.351                 True
# initial_seasons.352           -0.2681318                s.352                 True
# initial_seasons.353           -0.6479914                s.353                 True
# initial_seasons.354           -1.3284745                s.354                 True
# initial_seasons.355           -0.4844208                s.355                 True
# initial_seasons.356           -1.3406615                s.356                 True
# initial_seasons.357            1.0527507                s.357                 True
# initial_seasons.358           -0.8288878                s.358                 True
# initial_seasons.359            0.9145162                s.359                 True
# initial_seasons.360           -1.1921047                s.360                 True
# initial_seasons.361           -0.7487124                s.361                 True
# initial_seasons.362            0.5696319                s.362                 True
# initial_seasons.363            1.3379816                s.363                 True
# initial_seasons.364           -0.7685848                s.364                 True
# ----------------------------------------------------------------------------------

# %%
#predicting the mean wind speed for the year 2023
prediction_test = fit_test.forecast(len(test))
prediction_test
# Out:
# 2023-01-01    10.028776
# 2023-01-02     9.698092
# 2023-01-03     9.066747
# 2023-01-04    10.185147
# 2023-01-05     9.728549
#                 ...
# 2023-10-27    10.898303
# 2023-10-28    11.372440
# 2023-10-29    11.546580
# 2023-10-30     9.220418
# 2023-10-31    11.269107
# Freq: D, Length: 304, dtype: float64

# %%
plt.figure(figsize=(20,12))
plt.plot(train, color = "black", label = "Original mean wind series")
plt.plot(fit_test.fittedvalues, color = "red", label = "smoothened series")
plt.plot(prediction_test, color="green", label = "forecast")
plt.legend()

# %%
plt.figure(figsize=(20, 8))
plt.plot(prediction_test, color="green", label="Forecast")
plt.legend()
plt.title("Exponential Smoothing Forecast")
plt.xlabel("Year")
plt.ylabel("Wind Speed (knots)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Evaluation of Model 4

# %%
tes_mean_absolute_error = mean_absolute_error(
    train,
    fit_test.fittedvalues
)

tes_mean_squared_error = mean_squared_error(
    train,
    fit_test.fittedvalues
)**0.5
tes_mean_absolute_perc_error = mean_absolute_percentage_error(
    train,
    fit_test.fittedvalues
)

print("SES- MAE: {:.3f}, RMSE: {:.3f}, MAPE: {:.3f}".format(tes_mean_absolute_error, tes_mean_squared_error, tes_mean_absolute_perc_error))
# Out:
# SES- MAE: 2.154, RMSE: 2.729, MAPE: 0.266

# %%
test_mean_absolute_error = mean_absolute_error(
    test,
    prediction_test
)

test_mean_squared_error = mean_squared_error(
    test,
    prediction_test
)**0.5
test_mean_absolute_perc_error = mean_absolute_percentage_error(
    test,
    prediction_test
)

print("SES- MAE: {:.3f}, RMSE: {:.3f}, MAPE: {:.3f}".format(test_mean_absolute_error, test_mean_squared_error, test_mean_absolute_perc_error))
# Out:
# SES- MAE: 2.849, RMSE: 3.507, MAPE: 0.391

# %% [markdown]
# ### Model 5 - ARIMA (Autoregressive Integrated Moving Average Models)

# %%
weather_model5 = weather_data.copy()

# %%
year_range = range(2019, 2024)

# Setting 'year' as the index and filter only the rows within the specified range
weather_model5.set_index("year", inplace=True)
weather_model5 = weather_model5.loc[year_range]
weather_model5.reset_index(inplace=True)

# %%
weather_model5.index.freq = "MS"

# %%
weather_model5['date'] = pd.to_datetime(weather_model5['date'], format='%Y-%m-%d')
weather_model5.set_index('date', inplace=True)

# %%
train = weather_model5.loc["2019-01-01":"2022-12-31"]
print(train)
test = weather_model5.loc["2023-01-01":"2023-10-31"]
print(test)
# Out:
#             year  maxtp  mintp  gmin  rain     cbl  wdsp   pe evap
# date
# 2019-01-01  2019    9.2    1.8   6.9   0.2  1027.8   7.5  0.3  0.4
# 2019-01-02  2019    7.6    1.6    -1   0.0  1032.6   4.2  0.5  0.6
# 2019-01-03  2019    7.9    4.9  -1.6   0.0  1031.1   4.0  0.5  0.6
# 2019-01-04  2019    6.5    4.6   4.2   0.0  1030.9   4.8  0.7  0.9
# 2019-01-05  2019    8.4    2.0  -1.9   0.0  1027.7   5.2  0.4  0.5
# ...          ...    ...    ...   ...   ...     ...   ...  ...  ...
# 2022-12-27  2022   11.1    2.0   0.1   1.0  1001.0   9.5  0.5  0.6
# 2022-12-28  2022   11.3    5.0     2   5.2   983.5   9.8  0.5  0.6
# 2022-12-29  2022    9.6    4.7   3.2   0.8   982.6  12.2  0.7  0.8
# 2022-12-30  2022   11.4    6.9   3.1   2.5   975.3  12.8  0.8  0.9
# 2022-12-31  2022   10.0    5.3   4.4   2.6   982.7   3.7  0.3  0.4
#
# [1461 rows x 9 columns]
#             year  maxtp  mintp  gmin  rain     cbl  wdsp   pe evap
# date
# 2023-01-01  2023    6.8    1.3  -0.1   1.1   991.5   5.5  0.3  0.4
# 2023-01-02  2023    6.1    0.4  -0.5   0.0  1002.6   6.2  0.2  0.3
# 2023-01-03  2023   13.3    5.6  -3.2   1.5   996.3  12.5  0.8    1
# 2023-01-04  2023   12.6    8.8   7.9   0.1   998.7  13.7  0.9    1
# 2023-01-05  2023   12.6    6.7   7.4   2.7  1000.5  10.3  0.7  0.8
# ...          ...    ...    ...   ...   ...     ...   ...  ...  ...
# 2023-10-27  2023   13.2    4.1    -1   2.9   974.2   5.8  0.5  0.8
# 2023-10-28  2023   14.1    9.3   7.2   4.4   970.1   8.5  0.7    1
# 2023-10-29  2023   12.4    2.5  -1.2  11.1   972.0   5.2  0.4  0.6
# 2023-10-30  2023   12.7    1.7  -1.3   2.1   979.9   4.1  0.3  0.5
# 2023-10-31  2023   12.3    4.4   0.8   4.2   983.2   6.8  0.4  0.5
#
# [304 rows x 9 columns]

# %%
train["wdsp"].plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# Augmented Dickey-Fuller test To ckeck stationary data

# %%
def test_stationary(timeseries):
    
    print("--------------------------------------")
    print("Results of Dickey-Fuller test:")
    dftest = adfuller(train['wdsp'], autolag = 'AIC')
    dfoutput = pd.Series(dftest[0:4], index= ['Test statistic', 'p-value', 'Lags used', 'Number of observations'])
    for key,value in dftest[4].items():
        dfoutput['Confidence Interval (%s)'%key]=value
    print(dfoutput)

# %%
test_stationary(train['wdsp'])
# Out:
# --------------------------------------
# Results of Dickey-Fuller test:
# Test statistic              -1.575764e+01
# p-value                      1.202256e-28
# Lags used                    2.000000e+00
# Number of observations       1.458000e+03
# Confidence Interval (1%)    -3.434843e+00
# Confidence Interval (5%)    -2.863524e+00
# Confidence Interval (10%)   -2.567826e+00
# dtype: float64

# %% [markdown]
# As p-value is very small, it means it is the stationary data

# %% [markdown]
# As the data is the stationary data, there is no need to calculate the Differences.

# %%
#FirstDifference = (train["wdsp"] - train["wdsp"].shift(1)).dropna()

# %%
#FirstDifference.plot()

# %%
#round(adfuller(FirstDifference)[1],3)

# %% [markdown]
# Now we can produce autocorrelation and  partial autocorrelation function plots to try to determine the orders of p and q, the autoregressive and moving average

# %%
plot_acf(train["wdsp"], lags =10);

# %%
plot_pacf(train["wdsp"], lags =10);

# %% [markdown]
# The ACF plot shows a gradual decline, while the PACF plot cuts off after the first lag, suggesting an AR(1) model might be suitable. However, to confirm the most suitable model, will also fit close variations of this model, such as (1,0,0)(1,0,1)(1,0,2)(1,1,0)(1,1,1)(1,1,2)(2,1,0)(2,1,1)(1,2,1)(2,2,1)(0,1,1)(1,0,5)

# %% [markdown]
# #### ARIMA(1,0,0)

# %%
model100 = ARIMA(train["wdsp"], order = (1,0,0))
fit100 = model100.fit()
print(fit100.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   wdsp   No. Observations:                 1461
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3657.165
# Date:                Tue, 02 Jan 2024   AIC                           7320.331
# Time:                        23:44:34   BIC                           7336.191
# Sample:                    01-01-2019   HQIC                          7326.247
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.0954      0.174     52.193      0.000       8.754       9.437
# ar.L1          0.4941      0.021     23.231      0.000       0.452       0.536
# sigma2         8.7435      0.305     28.642      0.000       8.145       9.342
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):               129.74
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.93   Skew:                             0.64
# Prob(H) (two-sided):                  0.45   Kurtosis:                         3.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# #### ARIMA (1,0,1)

# %%
model101 = ARIMA(train["wdsp"], order = (1,0,1))
fit101 = model101.fit()
print(fit101.summary())
# Out:
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   wdsp   No. Observations:                 1461
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -3656.885
# Date:                Tue, 02 Jan 2024   AIC                           7321.770
# Time:                        23:44:34   BIC                           7342.918
# Sample:                    01-01-2019   HQIC                          7329.659
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.0952      0.179     50.922      0.000       8.745       9.445
# ar.L1          0.5299      0.044     11.919      0.000       0.443       0.617
# ma.L1         -0.0477      0.050     -0.947      0.344      -0.146       0.051
# sigma2         8.7402      0.305     28.662      0.000       8.142       9.338
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               130.10
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.93   Skew:                             0.64
# Prob(H) (two-sided):                  0.44   Kurtosis:                         3.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #### ARIMA (1,0,2)

# %%
model102 = ARIMA(train["wdsp"], order = (1,0,2))
fit102 = model102.fit()
print(fit102.summary())
# Out:
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   wdsp   No. Observations:                 1461
# Model:                 ARIMA(1, 0, 2)   Log Likelihood               -3651.598
# Date:                Tue, 02 Jan 2024   AIC                           7313.196
# Time:                        23:44:34   BIC                           7339.630
# Sample:                    01-01-2019   HQIC                          7323.056
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.0926      0.206     44.071      0.000       8.688       9.497
# ar.L1          0.7639      0.054     14.042      0.000       0.657       0.871
# ma.L1         -0.2843      0.059     -4.791      0.000      -0.401      -0.168
# ma.L2         -0.1599      0.041     -3.911      0.000      -0.240      -0.080
# sigma2         8.6771      0.302     28.762      0.000       8.086       9.268
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               130.48
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.93   Skew:                             0.64
# Prob(H) (two-sided):                  0.42   Kurtosis:                         3.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #### ARIMA(1,1,1)

# %%
model111 = ARIMA(train["wdsp"], order = (1,1,1))
fit111 = model111.fit()
print(fit111.summary())
# Out:
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   wdsp   No. Observations:                 1461
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -3655.039
# Date:                Tue, 02 Jan 2024   AIC                           7316.078
# Time:                        23:44:35   BIC                           7331.937
# Sample:                    01-01-2019   HQIC                          7321.994
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4604      0.022     21.043      0.000       0.418       0.503
# ma.L1         -0.9779      0.006   -170.096      0.000      -0.989      -0.967
# sigma2         8.7367      0.281     31.138      0.000       8.187       9.287
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               104.84
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.94   Skew:                             0.57
# Prob(H) (two-sided):                  0.47   Kurtosis:                         3.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #### ARIMA (1,0,5)

# %%
model105 = ARIMA(train["wdsp"], order = (1,0,5))
fit105 = model105.fit()
print(fit105.summary())
# Out:
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nikhi\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   wdsp   No. Observations:                 1461
# Model:                 ARIMA(1, 0, 5)   Log Likelihood               -3650.919
# Date:                Tue, 02 Jan 2024   AIC                           7317.839
# Time:                        23:44:35   BIC                           7360.134
# Sample:                    01-01-2019   HQIC                          7333.616
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.0931      0.202     44.918      0.000       8.696       9.490
# ar.L1          0.6871      0.132      5.196      0.000       0.428       0.946
# ma.L1         -0.2051      0.132     -1.552      0.121      -0.464       0.054
# ma.L2         -0.1199      0.068     -1.760      0.078      -0.253       0.014
# ma.L3          0.0043      0.038      0.113      0.910      -0.071       0.080
# ma.L4          0.0036      0.034      0.107      0.915      -0.063       0.070
# ma.L5          0.0387      0.032      1.225      0.221      -0.023       0.101
# sigma2         8.6689      0.302     28.662      0.000       8.076       9.262
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               129.01
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.93   Skew:                             0.63
# Prob(H) (two-sided):                  0.45   Kurtosis:                         3.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #### conclusion

# %% [markdown]
# The ARIMA (1,0,2) has the lowest AIC. Using auto_arima() we can automatically determine the model order.

# %%
auto_arima(train["wdsp"])
# Out:
# ARIMA(order=(1, 0, 2), scoring_args={}, suppress_warnings=True)

# %% [markdown]
# ### Diagnostic

# %% [markdown]
# #### ARIMA(1,0,2)

# %%
# Plot the diagnostics
fit102.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
acorr_ljungbox(fit102.resid, lags = 10)
# Out:
#      lb_stat  lb_pvalue
# 1   0.004102   0.948933
# 2   0.017079   0.991497
# 3   0.177485   0.981139
# 4   0.313805   0.988906
# 5   1.570584   0.904784
# 6   1.815391   0.935870
# 7   1.851646   0.967593
# 8   1.905178   0.983782
# 9   2.070185   0.990308
# 10  2.601669   0.989310

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### ARIMA (1,0,2)

# %%
#producing the forecast using the fitted model
predictions_102 = fit102.forecast(len(test))

# %%
predictions_102
# Out:
# 2023-01-01    6.654594
# 2023-01-02    8.374095
# 2023-01-03    8.543715
# 2023-01-04    8.673291
# 2023-01-05    8.772275
#                 ...
# 2023-10-27    9.092568
# 2023-10-28    9.092568
# 2023-10-29    9.092568
# 2023-10-30    9.092568
# 2023-10-31    9.092568
# Freq: D, Name: predicted_mean, Length: 304, dtype: float64

# %%
plt.figure(figsize = (20,8))
plt.plot(weather_model5["wdsp"], color = "green", label = "Original series")
plt.plot(fit102.fittedvalues, color = "red", label = "Fitted values")
plt.plot(predictions_102, color ="black", label ="Forecast")
plt.legend()

# %% [markdown]
# #### Evaluation of Model 5

# %%
arima_train_mean_absolute_error = mean_absolute_error(
    train["wdsp"],
    fit102.fittedvalues
)

arima_train_mean_squared_error = mean_squared_error(
    train["wdsp"],
    fit102.fittedvalues
)**0.5
arima_train_mean_absolute_perc_error = mean_absolute_percentage_error(
    train["wdsp"],
    fit102.fittedvalues
)

print("ARIMA(1,0,2) train- MAE: {:.3f}, RMSE: {:.3f}, MAPE: {:.3f}".format(arima_train_mean_absolute_error, arima_train_mean_squared_error, arima_train_mean_absolute_perc_error))
# Out:
# ARIMA(1,0,2) train- MAE: 2.317, RMSE: 2.946, MAPE: 0.289

# %%
arima_test_mean_absolute_error = mean_absolute_error(
    test["wdsp"],
    predictions_102
)

arima_test_mean_squared_error = mean_squared_error(
    test["wdsp"],
    predictions_102
)**0.5
arima_test_mean_absolute_perc_error = mean_absolute_percentage_error(
    test["wdsp"],
    predictions_102
)

print("ARIMA(1,0,2) test- MAE: {:.3f}, RMSE: {:.3f}, MAPE: {:.3f}".format(arima_test_mean_absolute_error, arima_test_mean_squared_error, arima_test_mean_absolute_perc_error))
# Out:
# ARIMA(1,0,2) test- MAE: 2.392, RMSE: 2.927, MAPE: 0.334
